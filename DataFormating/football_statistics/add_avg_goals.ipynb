# %%
import pandas as pd

from mean_stats import get_average_goals

# %% [markdown]
# # Import `compressed_final` dataset

# %%
compressed_final = pd.read_csv("../compressed_final.csv")

# %%
compressed_final.head()
# Out:
#      Stage  Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0  Group A    South Africa              1.0              1.0         Mexico
# 1  Group A         Uruguay              0.0              0.0         France
# 2  Group B  Korea Republic              2.0              0.0         Greece
# 3  Group B       Argentina              1.0              0.0        Nigeria
# 4  Group C         England              1.0              1.0            USA
#
#    Attendance  Half-time Home Goals  Half-time Away Goals Home Team Initials  \
# 0     84490.0                   0.0                   0.0                RSA
# 1     64100.0                   0.0                   0.0                URU
# 2     31513.0                   1.0                   0.0                KOR
# 3     55686.0                   1.0                   0.0                ARG
# 4     38646.0                   1.0                   1.0                ENG
#
#   Away Team Initials       ...        Player 11 Short passing Diff  \
# 0                MEX       ...                                 -42
# 1                FRA       ...                                 -14
# 2                GRE       ...                                  23
# 3                NGA       ...                                  -1
# 4                USA       ...                                  -4
#
#    Player 11 Shot power Diff  Player 11 Sliding tackle Diff  \
# 0                        -29                            -15
# 1                        -44                             -9
# 2                         -2                             39
# 3                        -25                             35
# 4                         -4                             -2
#
#    Player 11 Sprint speed Diff  Player 11 Stamina Diff  \
# 0                           -9                     -31
# 1                          -19                     -26
# 2                            7                      29
# 3                          -14                       7
# 4                           17                      -2
#
#    Player 11 Standing tackle Diff  Player 11 Strength Diff  \
# 0                             -17                        3
# 1                              -8                       -4
# 2                              40                      -10
# 3                              41                      -12
# 4                              -4                      -18
#
#    Player 11 Vision Diff  Player 11 Volleys Diff  FIFA Rank Diff
# 0                    -43                     -24            57.0
# 1                      9                     -58            10.0
# 2                    -16                      14            17.0
# 3                    -11                     -55           -42.0
# 4                     -7                      -5             0.0
#
# [5 rows x 418 columns]

# %% [markdown]
# # Add avg goals statistic to dataset

# %%
data = []
for i in range(len(compressed_final)):
    home_team_name = compressed_final["Home Team Name"][i]
    away_team_name = compressed_final["Away Team Name"][i]

    avg_goals = get_average_goals(home_team_name, away_team_name)
    if avg_goals:
        data.append(avg_goals[0]-avg_goals[1])
    else:
        data.append(0.0)

# %%
compressed_final["Avg Goals Diff"] = data

# %%
compressed_final.head()
# Out:
#      Stage  Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0  Group A    South Africa              1.0              1.0         Mexico
# 1  Group A         Uruguay              0.0              0.0         France
# 2  Group B  Korea Republic              2.0              0.0         Greece
# 3  Group B       Argentina              1.0              0.0        Nigeria
# 4  Group C         England              1.0              1.0            USA
#
#    Attendance  Half-time Home Goals  Half-time Away Goals Home Team Initials  \
# 0     84490.0                   0.0                   0.0                RSA
# 1     64100.0                   0.0                   0.0                URU
# 2     31513.0                   1.0                   0.0                KOR
# 3     55686.0                   1.0                   0.0                ARG
# 4     38646.0                   1.0                   1.0                ENG
#
#   Away Team Initials       ...        Player 11 Shot power Diff  \
# 0                MEX       ...                              -29
# 1                FRA       ...                              -44
# 2                GRE       ...                               -2
# 3                NGA       ...                              -25
# 4                USA       ...                               -4
#
#    Player 11 Sliding tackle Diff  Player 11 Sprint speed Diff  \
# 0                            -15                           -9
# 1                             -9                          -19
# 2                             39                            7
# 3                             35                          -14
# 4                             -2                           17
#
#    Player 11 Stamina Diff  Player 11 Standing tackle Diff  \
# 0                     -31                             -17
# 1                     -26                              -8
# 2                      29                              40
# 3                       7                              41
# 4                      -2                              -4
#
#    Player 11 Strength Diff  Player 11 Vision Diff  Player 11 Volleys Diff  \
# 0                        3                    -43                     -24
# 1                       -4                      9                     -58
# 2                      -10                    -16                      14
# 3                      -12                    -11                     -55
# 4                      -18                     -7                      -5
#
#    FIFA Rank Diff  Avg Goals Diff
# 0            57.0        0.000000
# 1            10.0        0.500000
# 2            17.0        2.000000
# 3           -42.0        0.333333
# 4             0.0        0.000000
#
# [5 rows x 419 columns]

# %% [markdown]
# # Save datasets into CSV files

# %%
compressed_final.to_csv("../compressed_final.csv", index=0)
