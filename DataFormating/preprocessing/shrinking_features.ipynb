# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Import datasets

# %%
final = pd.read_csv("../final.csv")

# %%
final.head()
# Out:
#    Away Team Goals  Away Team Name  Home Team Goals Home Team Name  \
# 0              0.0          France              0.0        Uruguay
# 1              0.0         Nigeria              1.0      Argentina
# 2              0.0       Australia              4.0        Germany
# 3              1.0     Switzerland              0.0          Spain
# 4              1.0  Korea Republic              4.0      Argentina
#
#    Home Player 1 Overall  Home Player 2 Overall  Home Player 3 Overall  \
# 0                     59                     60                     62
# 1                     52                     56                     56
# 2                     56                     59                     60
# 3                     60                     62                     63
# 4                     52                     56                     56
#
#    Home Player 4 Overall  Home Player 5 Overall  Home Player 6 Overall  \
# 0                     66                     66                     66
# 1                     57                     60                     61
# 2                     61                     61                     62
# 3                     63                     65                     68
# 4                     57                     60                     61
#
#             ...            Away Player 2 Overall  Away Player 3 Overall  \
# 0           ...                               56                     56
# 1           ...                               56                     58
# 2           ...                               57                     57
# 3           ...                               57                     60
# 4           ...                               60                     60
#
#    Away Player 4 Overall  Away Player 5 Overall  Away Player 6 Overall  \
# 0                     60                     60                     62
# 1                     59                     61                     61
# 2                     59                     59                     59
# 3                     61                     62                     62
# 4                     60                     60                     60
#
#    Away Player 7 Overall  Away Player 8 Overall  Away Player 9 Overall  \
# 0                     62                     63                     63
# 1                     62                     62                     63
# 2                     62                     62                     63
# 3                     63                     64                     64
# 4                     60                     60                     60
#
#    Away Player 10 Overall  Away Player 11 Overall
# 0                      64                      64
# 1                      64                      65
# 2                      64                      64
# 3                      65                      66
# 4                      62                      67
#
# [5 rows x 26 columns]

# %%
len(final)
# Out:
# 603

# %% [markdown]
# # Combine features

# %%
final.columns
# Out:
# Index(['Away Team Goals', 'Away Team Name', 'Home Team Goals',
#        'Home Team Name', 'Home Player 1 Overall', 'Home Player 2 Overall',
#        'Home Player 3 Overall', 'Home Player 4 Overall',
#        'Home Player 5 Overall', 'Home Player 6 Overall',
#        'Home Player 7 Overall', 'Home Player 8 Overall',
#        'Home Player 9 Overall', 'Home Player 10 Overall',
#        'Home Player 11 Overall', 'Away Player 1 Overall',
#        'Away Player 2 Overall', 'Away Player 3 Overall',
#        'Away Player 4 Overall', 'Away Player 5 Overall',
#        'Away Player 6 Overall', 'Away Player 7 Overall',
#        'Away Player 8 Overall', 'Away Player 9 Overall',
#        'Away Player 10 Overall', 'Away Player 11 Overall'],
#       dtype='object')

# %%
columns = list(final.columns[:4])

for i in range(1, 12):
    columns.append("Player " + str(i) + " Overall Diff")

# %%
compressed_final = pd.DataFrame(columns=columns)

# %%
for i in range(len(final)):
    data = list(
        final.iloc[i][final.columns[:4]]
    )
    
    
    for j in range(1, 12):
        home_player_stats = final.iloc[i]["Home Player " + str(j) + " Overall"]
        away_player_stats = final.iloc[i]["Away Player " + str(j) + " Overall"]

        try:
            data.append(int(home_player_stats) - int(away_player_stats))
        except:
            if "+" in str(home_player_stats):
                home_player_stats = home_player_stats.split("+")
                home_player_stats = int(home_player_stats[0]) + int(home_player_stats[1])
            if "+" in str(away_player_stats):
                away_player_stats = away_player_stats.split("+")
                away_player_stats = int(away_player_stats[0]) + int(away_player_stats[1])
                
            if "-" in str(home_player_stats):
                home_player_stats = home_player_stats.split("-")
                home_player_stats = int(home_player_stats[0]) - int(home_player_stats[1])
            if "-" in str(away_player_stats):
                away_player_stats = away_player_stats.split("-")
                away_player_stats = int(away_player_stats[0]) - int(away_player_stats[1])
                    
            data.append(int(home_player_stats) - int(away_player_stats))

    compressed_final = compressed_final.append(
        pd.Series(data, index=compressed_final.columns),
        ignore_index=True
    )

# %%
compressed_final.head()
# Out:
#    Away Team Goals  Away Team Name  Home Team Goals Home Team Name  \
# 0              0.0          France              0.0        Uruguay
# 1              0.0         Nigeria              1.0      Argentina
# 2              0.0       Australia              4.0        Germany
# 3              1.0     Switzerland              0.0          Spain
# 4              1.0  Korea Republic              4.0      Argentina
#
#   Player 1 Overall Diff Player 2 Overall Diff Player 3 Overall Diff  \
# 0                     7                     4                     6
# 1                     0                     0                    -2
# 2                     3                     2                     3
# 3                     6                     5                     3
# 4                    -4                    -4                    -4
#
#   Player 4 Overall Diff Player 5 Overall Diff Player 6 Overall Diff  \
# 0                     6                     6                     4
# 1                    -2                    -1                     0
# 2                     2                     2                     3
# 3                     2                     3                     6
# 4                    -3                     0                     1
#
#   Player 7 Overall Diff Player 8 Overall Diff Player 9 Overall Diff  \
# 0                     5                     5                     5
# 1                     0                     0                    -1
# 2                     0                     0                     2
# 3                     5                     5                     5
# 4                     2                     2                     2
#
#   Player 10 Overall Diff Player 11 Overall Diff
# 0                      5                      5
# 1                      0                     -1
# 2                      1                      2
# 3                      5                      4
# 4                      2                     -3

# %% [markdown]
# # Save datasets into CSV file

# %%
compressed_final.to_csv("../compressed_final.csv", index=0)
