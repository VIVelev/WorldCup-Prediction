# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Import datasets

# %%
final = pd.read_csv("../DataFormating/final.csv")
compressed_final = pd.read_csv("../DataFormating/compressed_final.csv")

# %% [markdown]
# # Explore

# %%
compressed_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Columns: 419 entries, Stage to Mean Away Team Goals
# dtypes: float64(7), int64(407), object(5)
# memory usage: 464.9+ KB

# %%
compressed_final.describe()
# Out:
#        Home Team Goals  Away Team Goals    Attendance  Half-time Home Goals  \
# count       142.000000       142.000000    142.000000            142.000000
# mean          1.204225         1.225352  52803.514085              0.401408
# std           1.145690         1.349517  15302.525297              0.619538
# min           0.000000         0.000000  23871.000000              0.000000
# 25%           0.000000         0.000000  39432.500000              0.000000
# 50%           1.000000         1.000000  54213.500000              0.000000
# 75%           2.000000         2.000000  63214.500000              1.000000
# max           7.000000         7.000000  84490.000000              3.000000
#
#        Half-time Away Goals  Player 1 Age Diff  Player 1 Overall Diff  \
# count            142.000000         142.000000             142.000000
# mean               0.521127           0.028169               0.154930
# std                0.872904           5.558131               9.454104
# min                0.000000         -16.000000             -23.000000
# 25%                0.000000          -4.000000              -6.000000
# 50%                0.000000           0.500000              -1.000000
# 75%                1.000000           3.750000               7.000000
# max                5.000000          16.000000              25.000000
#
#        Player 1 Potential Diff  Player 1 Acceleration Diff  \
# count               142.000000                  142.000000
# mean                  0.119718                    1.457746
# std                  10.078755                   17.550989
# min                 -21.000000                  -52.000000
# 25%                  -7.000000                   -8.000000
# 50%                   0.000000                    1.000000
# 75%                   7.000000                   12.000000
# max                  25.000000                   42.000000
#
#        Player 1 Aggression Diff          ...           \
# count                142.000000          ...
# mean                  -0.253521          ...
# std                   25.938945          ...
# min                  -64.000000          ...
# 25%                  -19.750000          ...
# 50%                   -0.500000          ...
# 75%                   18.000000          ...
# max                   58.000000          ...
#
#        Player 11 Shot power Diff  Player 11 Sliding tackle Diff  \
# count                 142.000000                     142.000000
# mean                   -3.795775                      -4.380282
# std                    30.147048                      34.697422
# min                   -67.000000                     -64.000000
# 25%                   -27.000000                     -32.000000
# 50%                    -3.000000                      -5.000000
# 75%                    15.500000                      21.000000
# max                    61.000000                      71.000000
#
#        Player 11 Sprint speed Diff  Player 11 Stamina Diff  \
# count                   142.000000              142.000000
# mean                      0.612676               -2.295775
# std                      25.973759               26.394387
# min                     -53.000000              -59.000000
# 25%                     -15.750000              -24.750000
# 50%                       1.000000                1.000000
# 75%                      20.750000               14.750000
# max                      58.000000               57.000000
#
#        Player 11 Standing tackle Diff  Player 11 Strength Diff  \
# count                      142.000000               142.000000
# mean                        -4.943662                -1.767606
# std                         36.013940                15.950129
# min                        -71.000000               -35.000000
# 25%                        -33.500000               -11.000000
# 50%                         -4.500000                -2.000000
# 75%                         18.750000                 8.000000
# max                         67.000000                45.000000
#
#        Player 11 Vision Diff  Player 11 Volleys Diff  Mean Home Team Goals  \
# count             142.000000              142.000000            142.000000
# mean                0.795775               -3.169014              1.146009
# std                21.942394               30.710262              1.048790
# min               -50.000000              -69.000000              0.000000
# 25%               -15.500000              -29.000000              0.000000
# 50%                 0.000000               -2.500000              1.000000
# 75%                14.000000               22.750000              2.000000
# max                63.000000               79.000000              7.000000
#
#        Mean Away Team Goals
# count            142.000000
# mean               1.134507
# std                1.306082
# min                0.000000
# 25%                0.000000
# 50%                1.000000
# 75%                1.666667
# max                7.000000
#
# [8 rows x 414 columns]

# %%
compressed_final.head()
# Out:
#      Stage  Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0  Group A    South Africa              1.0              1.0         Mexico
# 1  Group A         Uruguay              0.0              0.0         France
# 2  Group B  Korea Republic              2.0              0.0         Greece
# 3  Group B       Argentina              1.0              0.0        Nigeria
# 4  Group C         England              1.0              1.0            USA
#
#    Attendance  Half-time Home Goals  Half-time Away Goals Home Team Initials  \
# 0     84490.0                   0.0                   0.0                RSA
# 1     64100.0                   0.0                   0.0                URU
# 2     31513.0                   1.0                   0.0                KOR
# 3     55686.0                   1.0                   0.0                ARG
# 4     38646.0                   1.0                   1.0                ENG
#
#   Away Team Initials          ...           Player 11 Shot power Diff  \
# 0                MEX          ...                                 -29
# 1                FRA          ...                                 -44
# 2                GRE          ...                                  -2
# 3                NGA          ...                                 -25
# 4                USA          ...                                  -4
#
#    Player 11 Sliding tackle Diff  Player 11 Sprint speed Diff  \
# 0                            -15                           -9
# 1                             -9                          -19
# 2                             39                            7
# 3                             35                          -14
# 4                             -2                           17
#
#    Player 11 Stamina Diff  Player 11 Standing tackle Diff  \
# 0                     -31                             -17
# 1                     -26                              -8
# 2                      29                              40
# 3                       7                              41
# 4                      -2                              -4
#
#    Player 11 Strength Diff  Player 11 Vision Diff  Player 11 Volleys Diff  \
# 0                        3                    -43                     -24
# 1                       -4                      9                     -58
# 2                      -10                    -16                      14
# 3                      -12                    -11                     -55
# 4                      -18                     -7                      -5
#
#    Mean Home Team Goals  Mean Away Team Goals
# 0                   1.0              1.000000
# 1                   0.5              0.000000
# 2                   2.0              0.000000
# 3                   2.0              1.666667
# 4                   1.0              1.000000
#
# [5 rows x 419 columns]

# %%
compressed_final.columns
# Out:
# Index(['Stage', 'Home Team Name', 'Home Team Goals', 'Away Team Goals',
#        'Away Team Name', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Home Team Initials', 'Away Team Initials',
#        ...
#        'Player 11 Shot power Diff', 'Player 11 Sliding tackle Diff',
#        'Player 11 Sprint speed Diff', 'Player 11 Stamina Diff',
#        'Player 11 Standing tackle Diff', 'Player 11 Strength Diff',
#        'Player 11 Vision Diff', 'Player 11 Volleys Diff',
#        'Mean Home Team Goals', 'Mean Away Team Goals'],
#       dtype='object', length=419)

# %%
plt.figure(figsize=(25, 10))
sns.countplot("Stage", data=compressed_final)
