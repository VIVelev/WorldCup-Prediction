# %%
import pandas as pd

from mean_stats import get_average_goals

# %% [markdown]
# # Import `compressed_final` dataset

# %%
compressed_final = pd.read_csv("../compressed_final.csv")

# %%
compressed_final.head()
# Out:
#      Year              Datetime    Stage  Home Team Name  Home Team Goals  \
# 0  2010.0  11 Jun 2010 - 16:00   Group A    South Africa              1.0
# 1  2010.0  11 Jun 2010 - 20:30   Group A         Uruguay              0.0
# 2  2010.0  12 Jun 2010 - 13:30   Group B  Korea Republic              2.0
# 3  2010.0  12 Jun 2010 - 16:00   Group B       Argentina              1.0
# 4  2010.0  12 Jun 2010 - 20:30   Group C         England              1.0
#
#    Away Team Goals Away Team Name  Attendance  Half-time Home Goals  \
# 0              1.0         Mexico     84490.0                   0.0
# 1              0.0         France     64100.0                   0.0
# 2              0.0         Greece     31513.0                   1.0
# 3              0.0        Nigeria     55686.0                   1.0
# 4              1.0            USA     38646.0                   1.0
#
#    Half-time Away Goals         ...          Player 2 Stats Diff  \
# ...

# %% [markdown]
# # Add mean statistic to dataset

# %%
new_compressed_final = pd.DataFrame(
    columns=list(compressed_final.columns) + ["Mean Home Team Goals", "Mean Away Team Goals"]
)

# %%
for i in range(len(compressed_final)):
    data = list(compressed_final.iloc[i])
    res = get_average_goals(data[3], data[6])
    if res != 0:
        data.append(res[0])
        data.append(res[1])
    else:
        data.append(0)
        data.append(0)
        
    new_compressed_final = new_compressed_final.append(
        pd.Series(data, index=new_compressed_final.columns),
        ignore_index=True
    )

# %%
compressed_final = new_compressed_final

compressed_final.head()
# Out:
#      Year              Datetime    Stage  Home Team Name  Home Team Goals  \
# 0  2010.0  11 Jun 2010 - 16:00   Group A    South Africa              1.0
# 1  2010.0  11 Jun 2010 - 20:30   Group A         Uruguay              0.0
# 2  2010.0  12 Jun 2010 - 13:30   Group B  Korea Republic              2.0
# 3  2010.0  12 Jun 2010 - 16:00   Group B       Argentina              1.0
# 4  2010.0  12 Jun 2010 - 20:30   Group C         England              1.0
#
#    Away Team Goals Away Team Name  Attendance  Half-time Home Goals  \
# 0              1.0         Mexico     84490.0                   0.0
# 1              0.0         France     64100.0                   0.0
# 2              0.0         Greece     31513.0                   1.0
# 3              0.0        Nigeria     55686.0                   1.0
# 4              1.0            USA     38646.0                   1.0
#
#    Half-time Away Goals         ...          Player 4 Stats Diff  \
# ...

# %% [markdown]
# # Save datasets into CSV files

# %%
compressed_final.to_csv("../compressed_final.csv", index=0)
